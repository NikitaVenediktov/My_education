# %% [markdown]
# https://towardsdatascience.com/pandas-python-tricks-for-data-science-data-analysis-part-2-dc36460de90d
#
# ## удаление дубликатов из списка
# При попытке удалить дубликаты из списка вы можете попытаться использовать подход 𝗳𝗼𝗿 loop.
#
# Это работает, но неэффективно ❌ при работе с очень большими данными.
#
# Вместо этого используйте 𝘀𝗲𝘁() ✅, который изначально не принимает дубликаты.
#
# Ниже приведена иллюстрация 💡.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Дубликаты в исходном списке
# Использование 𝘀𝗲𝘁() для удаления дубликатов из списков - отличный подход.
#
# Но будьте осторожны с его использованием, так как он НЕ ❌ сохраняет исходный порядок. Используйте его только тогда, когда порядок элементов в списке вам не важен.
#
# Вместо этого используйте 𝗱𝗶𝗰𝘁.𝗳𝗿𝗼𝗺𝗸𝗲𝘆𝘀() ✅, чтобы сохранить исходный порядок.
#
# Ниже приведена иллюстрация 💡
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Проверьте, существует ли элемент в списке
# #Python Tricks ✨🐍✨
#
# При попытке 𝗰𝗵𝗲𝗰𝗸 𝗶𝗳 𝗮𝗻 𝗶𝘁𝗲𝗺 𝗲𝘅𝗶𝘀𝘁𝘀 𝗶𝗻 𝗮 𝗹𝗶𝘀𝘁, вы можете попытаться использовать подход 𝗳𝗼𝗿 цикла и 𝗶𝗳 условия.
#
# Это работает, но неэффективно ❌ при работе с очень большими данными.
#
# Вместо этого используйте подход 𝗶𝗻 ✅, который изначально возвращает булево значение.
#
# Ниже приведена иллюстрация 💡
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Получение N наибольших и наименьших значений в списке Python
# Максимальное и минимальное значения списка в Python можно найти с помощью функций 𝗺𝗮𝘅() и 𝗺𝗶𝗻() соответственно.
#
# Однако, когда необходимо получить значения 𝗡 𝗹𝗮𝗿𝗴𝗲𝘀𝘁 или 𝘀𝗺𝗮𝗹𝗹𝗲𝘀𝘁, можно подумать о двустороннем подходе:
#
# 1️⃣ Отсортируйте список в порядке убывания или возрастания.
#
# 2️⃣ Извлеките N наибольших или наименьших значений.
#
# Хорошая стратегия, НО не эффективная ❌ при работе с большими данными.
#
# ✅ Вместо этого вы можете использовать функции 𝗻𝗹𝗮𝗿𝗴𝗲𝘀𝘁 и 𝗻𝘀𝗺𝗮𝗹𝗹𝗲𝘀𝘁 из встроенного модуля Python 𝗵𝗲𝗮𝗽𝗾, который работает быстро 🚀 и экономит память 👍.
#
# ![image.png](attachment:image.png)
