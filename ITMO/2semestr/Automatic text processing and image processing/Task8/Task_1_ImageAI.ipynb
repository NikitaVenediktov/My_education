# %% [markdown]
# # Task 1: Human recognition using ImageAI

# %%
# Area for modules installation
# !pip install imageai==2.1.5
# !pip install torch
# !pip install torchvision
# !pip install tensorflow
# !pip install wget
# !wget -P model_data https://pjreddie.com/media/files/yolov3.weights
# !git clone https://github.com/dvolchek/YOLOv3-TensorFlow-2.x.git
# Out:
# Collecting imageai==2.1.5
#   Downloading imageai-2.1.5-py3-none-any.whl (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.6/180.6 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from imageai==2.1.5) (1.10.0)
# Requirement already satisfied: h5py in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from imageai==2.1.5) (3.8.0)
# Requirement already satisfied: matplotlib in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from imageai==2.1.5) (3.7.0)
# Requirement already satisfied: pillow in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from imageai==2.1.5) (9.4.0)
# Requirement already satisfied: numpy in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from imageai==2.1.5) (1.24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from matplotlib->imageai==2.1.5) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from matplotlib->imageai==2.1.5) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from matplotlib->imageai==2.1.5) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from matplotlib->imageai==2.1.5) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from matplotlib->imageai==2.1.5) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from matplotlib->imageai==2.1.5) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from matplotlib->imageai==2.1.5) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from matplotlib->imageai==2.1.5) (5.10.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->imageai==2.1.5) (3.13.0)
# Requirement already satisfied: six>=1.5 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->imageai==2.1.5) (1.16.0)
# Installing collected packages: imageai
#   Attempting uninstall: imageai
#     Found existing installation: imageai 3.0.3
#     Uninstalling imageai-3.0.3:
#       Successfully uninstalled imageai-3.0.3
# Successfully installed imageai-2.1.5
# Requirement already satisfied: torch in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: filelock in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch) (3.12.0)
# Requirement already satisfied: sympy in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch) (1.12)
# Requirement already satisfied: typing-extensions in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch) (4.4.0)
# Requirement already satisfied: networkx in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: torchvision in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (0.15.2)
# Requirement already satisfied: numpy in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torchvision) (1.24.2)
# Requirement already satisfied: torch==2.0.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: requests in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torchvision) (2.28.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: jinja2 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: networkx in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: sympy in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (1.12)
# Requirement already satisfied: typing-extensions in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (4.4.0)
# Requirement already satisfied: filelock in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from requests->torchvision) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from jinja2->torch==2.0.1->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Requirement already satisfied: tensorflow in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (2.13.0rc1)
# Requirement already satisfied: tensorflow-macos==2.13.0-rc1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow) (2.13.0rc1)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.3.0)
# Requirement already satisfied: numpy>=1.22 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.24.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.15.0)
# Requirement already satisfied: packaging in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (23.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.13.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (4.23.2)
# Requirement already satisfied: setuptools in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (65.6.3)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0rc0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.13.0rc0)
# Requirement already satisfied: keras<2.14,>=2.13.1rc0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.13.1rc0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (4.4.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (23.5.26)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (16.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.54.2)
# Requirement already satisfied: h5py>=2.9.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (3.8.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0-rc1->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.19.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.28.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.3.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.4.3)
# Requirement already satisfied: urllib3<2.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (1.26.14)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (5.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (6.6.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.13.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.2.2)
# Requirement already satisfied: wget in /Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages (3.2)
# fatal: destination path 'YOLOv3-TensorFlow-2.x' already exists and is not an empty directory.

# %%
# Importing required modules and setting up environment
import warnings
warnings.filterwarnings('ignore')
from imageai.Detection import ObjectDetection
from IPython.display import Image
import pandas as pd
import os

# %%
# Function for counting of number of found people on an image
def human_counter(image_data):
    counter = 0
    for record in image_data:
        if record['name'] == 'person':
            counter+=1
    return counter

# %%
# !wget -P model_data https://pjreddie.com/media/files/yolov3.weights
# Out:
# zsh:1: command not found: wget

# %%
# Paths to images
models_path = 'models/'
image_path = 'images/'
image_processed_path = 'images_processed/'

# Getting list of available images
images_available = os.listdir(image_path)
print(images_available)
# Out:
# ['img_10.jpg', 'img_1.jpg', 'img_2.jpg', 'img_3.jpg', 'img_7.jpg', 'img_6.jpg', 'img_4.jpg', 'img_5.jpg', 'img_8.jpg', 'img_9.jpg']

# %%
# Setting up RetinaNet detector
# detector_RN = ObjectDetection()
# detector_RN.setModelTypeAsRetinaNet() 
# detector_RN.setModelPath(models_path + 'resnet50_coco_best_v2.0.1.h5') 
# detector_RN.loadModel()

# Setting up YOLO detector
detector_YOLO = ObjectDetection()
detector_YOLO.setModelTypeAsYOLOv3() 
detector_YOLO.setModelPath(models_path + 'yolov3.h5')  
detector_YOLO.loadModel()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 8
#       1 # Setting up RetinaNet detector
#       2 # detector_RN = ObjectDetection()
#       3 # detector_RN.setModelTypeAsRetinaNet()
#    (...)
#       6
#       7 # Setting up YOLO detector
# ----> 8 detector_YOLO = ObjectDetection()
#       9 detector_YOLO.setModelTypeAsYOLOv3()
#      10 detector_YOLO.setModelPath(models_path + 'yolov3.h5')
#
# File ~/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages/imageai/Detection/__init__.py:69, in __init__(self)
#      51 self.__input_image_min = 1333
#      52 self.__input_image_max = 800
#      54 self.numbers_to_names = {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus',
#      55                          6: 'train',
#      56                          7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign',
#      57                          12: 'parking meter',
#      58                          13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow',
#      59                          20: 'elephant',
#      60                          21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag',
#      61                          27: 'tie',
#      62                          28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball',
#      63                          33: 'kite',
#      64                          34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard',
#      65                          38: 'tennis racket',
#      66                          39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon',
#      67                          45: 'bowl',
#      68                          46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot',
# ---> 69                          52: 'hot dog',
#      70                          53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant',
#      71                          59: 'bed',
#      72                          60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote',
#      73                          66: 'keyboard',
#      74                          67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink',
#      75                          72: 'refrigerator',
#      76                          73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear',
#      77                          78: 'hair dryer',
#      78                          79: 'toothbrush'}
#      80 # Unique instance variables for YOLOv3 and TinyYOLOv3 model
#      81 self.__yolo_iou = 0.45
#
# File ~/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages/imageai/Detection/__init__.py:76, in __load_classes(self, path)
#      51 self.__input_image_min = 1333
#      52 self.__input_image_max = 800
#      54 self.numbers_to_names = {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus',
#      55                          6: 'train',
#      56                          7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign',
#      57                          12: 'parking meter',
#      58                          13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow',
#      59                          20: 'elephant',
#      60                          21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag',
#      61                          27: 'tie',
#      62                          28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball',
#      63                          33: 'kite',
#      64                          34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard',
#      65                          38: 'tennis racket',
#      66                          39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon',
#      67                          45: 'bowl',
#      68                          46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot',
#      69                          52: 'hot dog',
#      70                          53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant',
#      71                          59: 'bed',
#      72                          60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote',
#      73                          66: 'keyboard',
#      74                          67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink',
#      75                          72: 'refrigerator',
# ---> 76                          73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear',
#      77                          78: 'hair dryer',
#      78                          79: 'toothbrush'}
#      80 # Unique instance variables for YOLOv3 and TinyYOLOv3 model
#      81 self.__yolo_iou = 0.45
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/nikitav/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages/imageai/Detection/coco_classes.txt'

# %%
# Array of true number of people on every image
people_true_number = [4, 5, 7, 4, 4, 5, 6, 4, 5, 6]

# %%
results_array = []
#results_array.append(['image/model', 'RetinaNet50', 'RetinaNet80', 'YOLO50', 'YOLO80'])

for image_number in range(1,10+1):
    
    # Initializing row array
    temp_array = []

    # Adding image number
    temp_array.append(image_number)
    
    # Adding info about real number of people on the image
    temp_array.append(people_true_number[image_number-1])

    # # Using RetinaNet with 50% cutoff
    # image_data = detector_RN.detectObjectsFromImage(
    # input_image = image_path + str(image_number) + '.jpg',
    # output_image_path = image_processed_path + str(image_number) + '_RN_Cutoff_50' + '.jpg',
    # minimum_percentage_probability = 50 # Cutoff threshold
    # )
    # temp_array.append(human_counter(image_data))
    
    # # Using RetinaNet with 80% cutoff
    # image_data = detector_RN.detectObjectsFromImage(
    # input_image = image_path + str(image_number) + '.jpg',
    # output_image_path = image_processed_path + str(image_number) + '_RN_Cutoff_80' + '.jpg',
    # minimum_percentage_probability = 80 # Cutoff threshold
    # )
    # temp_array.append(human_counter(image_data))
    
    # Using YOLO with 50% cutoff
    image_data = detector_YOLO.detectObjectsFromImage(
    input_image = image_path + str(image_number) + '.jpg',
    output_image_path = image_processed_path + str(image_number) + '_YOLO_Cutoff_50' + '.jpg',
    minimum_percentage_probability = 50 # Cutoff threshold
    )
    temp_array.append(human_counter(image_data))
    
    # Using YOLO with 80% cutoff
    image_data = detector_YOLO.detectObjectsFromImage(
    input_image = image_path + str(image_number) + '.jpg',
    output_image_path = image_processed_path + str(image_number) + '_YOLO_Cutoff_80' + '.jpg',
    minimum_percentage_probability = 80 # Cutoff threshold
    )
    temp_array.append(human_counter(image_data))
    
    # Adding entire row into resulting array
    results_array.append(temp_array)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 16
#      13 temp_array.append(people_true_number[image_number-1])
#      15 # Using RetinaNet with 50% cutoff
# ---> 16 image_data = detector_RN.detectObjectsFromImage(
#      17 input_image = image_path + str(image_number) + '.jpg',
#      18 output_image_path = image_processed_path + str(image_number) + '_RN_Cutoff_50' + '.jpg',
#      19 minimum_percentage_probability = 50 # Cutoff threshold
#      20 )
#      21 temp_array.append(human_counter(image_data))
#      23 # Using RetinaNet with 80% cutoff
#
# File ~/Desktop/ITMO/my_courses/My_education/.conda/lib/python3.9/site-packages/imageai/Detection/__init__.py:322, in detectObjectsFromImage(self, input_image, output_image_path, output_type, extract_detected_objects, minimum_percentage_probability, display_percentage_probability, display_object_name, display_box, custom_objects)
#     320 try:
#     321     if (self.__modelType == "retinanet"):
# --> 322         output_objects_array = []
#     323         detected_objects_image_array = []
#     325         if (input_type == "file"):
#
# AttributeError: 'NoneType' object has no attribute 'eval'

# %%
# Results visualization
table_columns_names = ['Image number', 'True value', 'RetinaNet50', 'RetinaNet80', 'YOLO50', 'YOLO80']
pd.DataFrame(results_array, columns = table_columns_names)
# Out:
#    Image number  True value  RetinaNet50  RetinaNet80  YOLO50  YOLO80
# 0             1           4            5            4       4       4
# 1             2           5            6            1       5       4
# 2             3           7            5            2       6       5
# 3             4           4            4            2       4       3
# 4             5           4            5            4       4       4
# 5             6           5            5            4       5       5
# 6             7           6            6            6       6       6
# 7             8           4            4            4       4       4
# 8             9           5            5            5       5       5
# 9            10           6            5            3       4       4

# %%
# Creating dictionary for results storage
all_results = {}

for model_type in range(2, 5+1):
    
    # Arranging array for model resutls
    model_results_array = []
    
    # Iterating through rows
    for i in range(0, 9+1):
        
        # Getting current values
        true_value = results_array[i][1]
        predicted_value = results_array[i][model_type]
    
        # Distributing obtained results
        if true_value >= predicted_value:
            TP = predicted_value
            TN = 0
            FP = 0
            FN = true_value - predicted_value
        else:
            TP = true_value
            TN = 0
            FP = predicted_value - true_value
            FN = 0
    
        # Adding metrics to array
        model_results_array.append([TP, TN, FP, FN])
    
    model_results_array.append([sum(row[0] for row in model_results_array),
                                sum(row[1] for row in model_results_array),
                                sum(row[2] for row in model_results_array),
                                sum(row[3] for row in model_results_array)])
    all_results.update({table_columns_names[model_type]: model_results_array})
    
print(all_results)
# Out:
# {'RetinaNet50': [[4, 0, 1, 0], [5, 0, 1, 0], [5, 0, 0, 2], [4, 0, 0, 0], [4, 0, 1, 0], [5, 0, 0, 0], [6, 0, 0, 0], [4, 0, 0, 0], [5, 0, 0, 0], [5, 0, 0, 1], [47, 0, 3, 3]], 'RetinaNet80': [[4, 0, 0, 0], [1, 0, 0, 4], [2, 0, 0, 5], [2, 0, 0, 2], [4, 0, 0, 0], [4, 0, 0, 1], [6, 0, 0, 0], [4, 0, 0, 0], [5, 0, 0, 0], [3, 0, 0, 3], [35, 0, 0, 15]], 'YOLO50': [[4, 0, 0, 0], [5, 0, 0, 0], [6, 0, 0, 1], [4, 0, 0, 0], [4, 0, 0, 0], [5, 0, 0, 0], [6, 0, 0, 0], [4, 0, 0, 0], [5, 0, 0, 0], [4, 0, 0, 2], [47, 0, 0, 3]], 'YOLO80': [[4, 0, 0, 0], [4, 0, 0, 1], [5, 0, 0, 2], [3, 0, 0, 1], [4, 0, 0, 0], [5, 0, 0, 0], [6, 0, 0, 0], [4, 0, 0, 0], [5, 0, 0, 0], [4, 0, 0, 2], [44, 0, 0, 6]]}

# %%
# Preparing rows and columns names
result_columns_names = ['TP', 'TN', 'FP', 'FN']
row_indexes = list(range(1, 10+1))
row_indexes.append('sum')

# %% [markdown]
# ### 1. Displaying results for RetinaNet with threshold of 50%

# %%
pd.DataFrame(all_results['RetinaNet50'], columns = result_columns_names, index = row_indexes)
# Out:
#      TP  TN  FP  FN
# 1     4   0   1   0
# 2     5   0   1   0
# 3     5   0   0   2
# 4     4   0   0   0
# 5     4   0   1   0
# 6     5   0   0   0
# 7     6   0   0   0
# 8     4   0   0   0
# 9     5   0   0   0
# 10    5   0   0   1
# sum  47   0   3   3

# %% [markdown]
# ### 2. Displaying results for RetinaNet with threshold of 80%

# %%
pd.DataFrame(all_results['RetinaNet80'], columns = result_columns_names, index = row_indexes)
# Out:
#      TP  TN  FP  FN
# 1     4   0   0   0
# 2     1   0   0   4
# 3     2   0   0   5
# 4     2   0   0   2
# 5     4   0   0   0
# 6     4   0   0   1
# 7     6   0   0   0
# 8     4   0   0   0
# 9     5   0   0   0
# 10    3   0   0   3
# sum  35   0   0  15

# %% [markdown]
# ### 3. Displaying results for YOLO with threshold of 50%

# %%
pd.DataFrame(all_results['YOLO50'], columns = result_columns_names, index = row_indexes)
# Out:
#      TP  TN  FP  FN
# 1     4   0   0   0
# 2     5   0   0   0
# 3     6   0   0   1
# 4     4   0   0   0
# 5     4   0   0   0
# 6     5   0   0   0
# 7     6   0   0   0
# 8     4   0   0   0
# 9     5   0   0   0
# 10    4   0   0   2
# sum  47   0   0   3

# %% [markdown]
# ### 4. Displaying results for YOLO with threshold of 80%

# %%
pd.DataFrame(all_results['YOLO80'], columns = result_columns_names, index = row_indexes)
# Out:
#      TP  TN  FP  FN
# 1     4   0   0   0
# 2     4   0   0   1
# 3     5   0   0   2
# 4     3   0   0   1
# 5     4   0   0   0
# 6     5   0   0   0
# 7     6   0   0   0
# 8     4   0   0   0
# 9     5   0   0   0
# 10    4   0   0   2
# sum  44   0   0   6

# %% [markdown]
# ### 5. F-measure calculation for every model

# %%
for key, value in all_results.items():
    TP = value[10][0]
    FP = value[10][2]
    FN = value[10][3]
    f_measure = TP / (TP + (FP + FN)/2)
    print('For ' + key + ' f-measure is: ' + str(f_measure))
# Out:
# For RetinaNet50 f-measure is: 0.94
# For RetinaNet80 f-measure is: 0.8235294117647058
# For YOLO50 f-measure is: 0.9690721649484536
# For YOLO80 f-measure is: 0.9361702127659575
